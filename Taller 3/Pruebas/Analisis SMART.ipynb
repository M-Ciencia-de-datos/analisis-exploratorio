# %% [markdown]
# # Analisis exploratorio

# %%
pip install pandas seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 11.3 MB 4.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 294 kB 13.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.3 MB 13.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 507 kB 11.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 346 kB 9.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.8 MB 10.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 64 kB 4.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.8 MB 11.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 107 kB 10.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 249 kB 6.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 10.3 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/sleep_cycle_productivity.csv")
df.head(10)
# Out:
#          Date  Person_ID  Age  Gender  Sleep Start Time  Sleep End Time  \
# 0  2024-04-12       1860   32   Other             23.33            4.61
# 1  2024-11-04       1769   41  Female             21.02            2.43
# 2  2024-08-31       2528   20    Male             22.10            3.45
# 3  2024-02-22       8041   37   Other             23.10            6.65
# 4  2024-02-23       4843   46   Other             21.42            4.17
# 5  2024-07-08       7439   38    Male             21.77            6.41
# 6  2024-01-09       6463   18   Other             22.83            6.87
# 7  2024-01-28       7278   26  Female             20.78            3.14
# 8  2024-04-10       9110   31   Other             20.07            3.37
# 9  2024-02-21       6116   49  Female             20.37            3.89
#
#    Total Sleep Hours  Sleep Quality  Exercise (mins/day)  \
# 0               5.28              3                   86
# 1               5.41              5                   32
# ...

# %%
from matplotlib import pyplot as plt
df.boxplot(column='Total Sleep Hours')
plt.show()

# %%
print(df.columns)  # Verifica los nombres de las columnas
# Out:
# Index(['Date', 'Person_ID', 'Age', 'Gender', 'Sleep Start Time',
#        'Sleep End Time', 'Total Sleep Hours', 'Sleep Quality',
#        'Exercise (mins/day)', 'Caffeine Intake (mg)',
#        'Screen Time Before Bed (mins)', 'Work Hours (hrs/day)',
#        'Productivity Score', 'Mood Score', 'Stress Level'],
#       dtype='object')

# %%
sns.kdeplot(df['Screen Time Before Bed (mins)'], shade=True)
plt.title('Screen Time Before Bed (mins)')
plt.show()
# Out:
# /var/folders/b6/5l72q00j6f78t_pqn5lf022h0000gn/T/ipykernel_50213/496653519.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Screen Time Before Bed (mins)'], shade=True)

# %%
from matplotlib import pyplot as plt
df.boxplot(column='Screen Time Before Bed (mins)')
plt.show()
